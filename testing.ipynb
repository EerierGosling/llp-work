# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import numpy as np
import matplotlib.pyplot as plt
import argparse
import wandb
import datetime
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 9
#       7 import matplotlib.pyplot as plt
#       8 import argparse
# ----> 9 import wandb
#      10 import datetime
#
# File ~/.local/lib/python3.9/site-packages/wandb/__init__.py:25
#      22 from wandb.sdk.lib import wb_logging as _wb_logging
#      23 _wb_logging.configure_wandb_logger()
# ---> 25 from wandb import sdk as wandb_sdk
#      27 import wandb
#      29 wandb.wandb_lib = wandb_sdk.lib  # type: ignore
#
# File ~/.local/lib/python3.9/site-packages/wandb/sdk/__init__.py:25
#       3 __all__ = (
#       4     "Config",
#       5     "Settings",
#    (...)
#      21     "helper",
#      22 )
#      24 from . import wandb_helper as helper
# ---> 25 from .artifacts.artifact import Artifact
#      26 from .wandb_alerts import AlertLevel
#      27 from .wandb_config import Config
#
# File ~/.local/lib/python3.9/site-packages/wandb/sdk/artifacts/artifact.py:30
#      27 import requests
#      29 import wandb
# ---> 30 from wandb import data_types, env
#      31 from wandb._iterutils import one
#      32 from wandb.apis.normalize import normalize_exceptions
#
# File ~/.local/lib/python3.9/site-packages/wandb/data_types.py:16
#       1 """This module defines data types for logging rich, interactive visualizations to W&B.
#       2
#       3 Data types include common media types, like images, audio, and videos,
#    (...)
#      13 and upload them to the W&B server.
#      14 """
# ---> 16 from .sdk.data_types.audio import Audio
#      17 from .sdk.data_types.base_types.media import BatchableMedia, Media
#      18 from .sdk.data_types.base_types.wb_value import WBValue
#
# File ~/.local/lib/python3.9/site-packages/wandb/sdk/data_types/audio.py:11
#       9 from . import _dtypes
#      10 from ._private import MEDIA_TMP
# ---> 11 from .base_types.media import BatchableMedia
#      13 if TYPE_CHECKING:
#      14     import numpy as np
#
# File ~/.local/lib/python3.9/site-packages/wandb/sdk/data_types/base_types/media.py:14
#      11 from wandb.sdk.lib import filesystem
#      12 from wandb.sdk.lib.paths import LogicalPath
# ---> 14 from .wb_value import WBValue
#      16 if TYPE_CHECKING:  # pragma: no cover
#      17     import numpy as np
#
# File ~/.local/lib/python3.9/site-packages/wandb/sdk/data_types/base_types/wb_value.py:4
#       1 from typing import TYPE_CHECKING, Any, ClassVar, Dict, List, Optional, Type, Union
#       3 from wandb import util
# ----> 4 from wandb.sdk import wandb_setup
#       6 if TYPE_CHECKING:  # pragma: no cover
#       7     from wandb.sdk.artifacts.artifact import Artifact
#
# File ~/.local/lib/python3.9/site-packages/wandb/sdk/wandb_setup.py:39
#      36 from wandb.env import CONFIG_DIR
#      37 from wandb.sdk.lib import import_hooks, wb_logging
# ---> 39 from . import wandb_settings
#      40 from .lib import config_util, server
#      42 if TYPE_CHECKING:
#
# File ~/.local/lib/python3.9/site-packages/wandb/sdk/wandb_settings.py:38
#      35 from wandb.errors import UsageError
#      36 from wandb.proto import wandb_settings_pb2
# ---> 38 from .lib import apikey, credentials, ipython
#      39 from .lib.gitlib import GitRepo
#      40 from .lib.run_moment import RunMoment
#
# File ~/.local/lib/python3.9/site-packages/wandb/sdk/lib/apikey.py:21
#      18 from requests.utils import NETRC_FILES, get_netrc_auth
#      20 import wandb
# ---> 21 from wandb.apis import InternalApi
#      22 from wandb.errors import term
#      23 from wandb.errors.links import url_registry
#
# File ~/.local/lib/python3.9/site-packages/wandb/apis/__init__.py:43
#      38     _disable_ssl()
#      41 reset_path = util.vendor_setup()
# ---> 43 from .internal import Api as InternalApi  # noqa
#      44 from .public import Api as PublicApi  # noqa
#      46 reset_path()
#
# File ~/.local/lib/python3.9/site-packages/wandb/apis/internal.py:3
#       1 from typing import Any
# ----> 3 from wandb.sdk.internal.internal_api import Api as InternalApi
#       6 class Api:
#       7     """Internal proxy to the official internal API."""
#
# File ~/.local/lib/python3.9/site-packages/wandb/sdk/internal/internal_api.py:53
#      50 from wandb.sdk.lib.gql_request import GraphQLSession
#      51 from wandb.sdk.lib.hashutil import B64MD5, md5_file_b64
# ---> 53 from ..lib import credentials, retry
#      54 from ..lib.filenames import DIFF_FNAME, METADATA_FNAME
#      55 from ..lib.gitlib import GitRepo
#
# File ~/.local/lib/python3.9/site-packages/wandb/sdk/lib/retry.py:28
#      24 SLEEP_FN = time.sleep
#      25 SLEEP_ASYNC_FN = asyncio.sleep
# ---> 28 class RetryCancelledError(wandb.errors.Error):
#      29     """A retry did not occur because it was cancelled."""
#      32 class TransientError(Exception):
#
# AttributeError: partially initialized module 'wandb' has no attribute 'errors' (most likely due to a circular import)

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--job_id', type=int, required=True)
job_id = parser.parse_args().job_id

config={
    "learning_rate": 0.001,
    "weight_decay": 0.01,
    "batch_size": 32,
    "architecture": "CNN",
    "dataset": "CIFAR-10",
    "epochs": 40,
    "epsilon": 0.01,  # adversarial perturbation strength
    "adversarial_ratio": 0.5,  # ratio of adversarial to clean examples
}

wandb.init(
    project="classfier-cifar10",
    name=f"{datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')}",
    config=config,
)


# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# https://docs.pytorch.org/tutorials/beginner/fgsm_tutorial.html
def fgsm_attack(image, epsilon, data_grad):
    # Collect the element-wise sign of the data gradient
    sign_data_grad = data_grad.sign()
    # Create the perturbed image by adjusting each pixel of the input image
    perturbed_image = image + epsilon*sign_data_grad
    # Adding clipping to maintain [0,1] range
    perturbed_image = torch.clamp(perturbed_image, 0, 1)
    # Return the perturbed image
    return perturbed_image

class Net(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.conv1 = nn.Conv2d(3, 64, 3, padding=1)
        self.conv2 = nn.Conv2d(64, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, 3, padding=1)
        self.conv5 = nn.Conv2d(128, 256, 3, padding=1)
        self.conv6 = nn.Conv2d(256, 256, 3, padding=1)
        
        self.pool = nn.MaxPool2d(2, 2)
        self.dropout_conv = nn.Dropout2d(0.25)
        self.dropout = nn.Dropout(0.5)
        
        self.bn1 = nn.BatchNorm2d(64)
        self.bn2 = nn.BatchNorm2d(128)
        self.bn3 = nn.BatchNorm2d(256)
        
        self.fc1 = nn.Linear(256 * 4 * 4, 512)
        self.fc2 = nn.Linear(512, 10)

    def forward(self, x):

        x = F.relu(self.bn1(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.dropout_conv(x)
        
        x = F.relu(self.bn2(self.conv3(x)))
        x = self.pool(F.relu(self.conv4(x)))
        x = self.dropout_conv(x)
        
        x = F.relu(self.bn3(self.conv5(x)))
        x = self.pool(F.relu(self.conv6(x)))
        x = self.dropout_conv(x)
        
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x
        
if __name__ == '__main__':
    print("starting")
    net = Net()
    net.to(device)

    criterion = nn.CrossEntropyLoss()
    trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=wandb.config.batch_size, shuffle=True, num_workers=2)

    testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
    testloader = torch.utils.data.DataLoader(testset, batch_size=wandb.config.batch_size, shuffle=False, num_workers=2)

    optimizer = optim.AdamW(net.parameters(), lr=wandb.config.learning_rate, weight_decay=wandb.config.weight_decay)
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=wandb.config.epochs)

    accuracy = []

    for epoch in range(wandb.config.epochs):
        epoch_loss = 0.0
        train_total = 0
        train_correct = 0
        adv_correct = 0
        net.train()
        
        for i, data in enumerate(trainloader, 0):

            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)  # Move data to GPU

            optimizer.zero_grad()

            # Clean training
            clean_outputs = net(inputs)
            clean_loss = criterion(clean_outputs, labels)
            
            # Adversarial training
            adv_inputs = fgsm_attack(net, inputs, labels, wandb.config.epsilon)
            adv_outputs = net(adv_inputs)
            adv_loss = criterion(adv_outputs, labels)
            
            # Combined loss
            total_loss = (1 - wandb.config.adversarial_ratio) * clean_loss + wandb.config.adversarial_ratio * adv_loss
            total_loss.backward()
            optimizer.step()

            epoch_loss += total_loss.item()

            # Calculate accuracy on clean examples
            _, predicted = torch.max(clean_outputs, 1)
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()
            
            # Calculate accuracy on adversarial examples
            _, adv_predicted = torch.max(adv_outputs, 1)
            adv_correct += (adv_predicted == labels).sum().item()
        
        net.eval()
        # testing the model
        test_correct = 0
        test_total = 0
        adv_test_correct = 0

        with torch.no_grad():
            for data in testloader:
                images, labels = data
                images, labels = images.to(device), labels.to(device)
                
                # Clean test accuracy
                outputs = net(images)
                _, predicted = torch.max(outputs, 1)
                test_total += labels.size(0)
                test_correct += (predicted == labels).sum().item()
                
                # Adversarial test accuracy
                adv_images = fgsm_attack(net, images, labels, wandb.config.epsilon)
                adv_outputs = net(adv_images)
                _, adv_predicted = torch.max(adv_outputs, 1)
                adv_test_correct += (adv_predicted == labels).sum().item()

        wandb.log({
            "train_acc": train_correct / train_total,
            "train_adv_acc": adv_correct / train_total,
            "test_acc": test_correct / test_total,
            "test_adv_acc": adv_test_correct / test_total,
            "loss": epoch_loss / len(trainloader)
        })
        scheduler.step()
        epoch_loss = 0.0

    PATH = f'./trained-models/cifar_net-adversarial-lr_{wandb.config.learning_rate}-eps_{wandb.config.epsilon}.pth'
    torch.save(net.state_dict(), PATH)

    wandb.finish()

    print("saved")
